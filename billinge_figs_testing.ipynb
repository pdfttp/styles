# %% [markdown]
# ### Dependencies:
#
# - numpy
# - matplotlib
# - seaborn

# %%
# %matplotlib inline
import os

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
def sohamSeabornStyle():
    sns.reset_orig()
    sns.set_style("ticks", {'grid.linestyle': '--',
                            'axes.linewidth': 2.5,
                            'axes.labelcolor':'black',
                            'grid.linewidth': 0.1,
                            'axes.edgecolor': '0.3',
                            'xtick.color':'black',
                            'ytick.color': 'black',
                            'xtick.direction': 'in',
                            'ytick.direction': 'in',
                             })
                                 

#     sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
    sns.set_context("notebook", font_scale=2.3, rc={"lines.linewidth": 1.5})

    # Fig Fonts, and override MathJax font
    mpl.rcParams['font.family']='Arial'
    mpl.rcParams['mathtext.default'] = 'regular'

# %%
def anotherstyle():
    sns.reset_orig()
    plt.style.use(os.path.join('./styles/', 'billinge.mplstyle'))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %% [markdown]
# ### Ex 1

# %%
sohamSeabornStyle()
sinplot()

# %% [markdown]
# ### Compare 1: current (draft) billinge.mplstyle

# %%
anotherstyle()
sinplot()

# %% [markdown]
# ### Ex 2

# %%
def NiPDF1(title=None):
    r1, g1, d1, c1 = np.loadtxt('./data/Ni.dat', skiprows=4).T

    fig, ax1 = plt.subplots(1, 1, figsize=[14,7])
    
#     ax1.plot([0.0],[0.0])
#     ax1.plot([0.0],[0.0])
#     ax1.plot(r1, d1-5)
    ax1.plot(r1, g1, lw=1, color='#18121E')
    ax1.plot(r1, g1-1, lw=1, color='#233237')
    ax1.plot(r1, g1-2, lw=1, color='#984B43')
    ax1.plot(r1, g1-3, lw=1, color='#EAC67A')
#     ax1.plot(r1, g1, lw=10, color='#18121E')
    #     ax1.plot(r1, c1, lw=2) 
   

    ax1.set_ylabel('$G(\AA^{-2})$' , fontsize=20)
    ax1.set_xlabel('$r(\AA)$' , fontsize=20)
    
    ax1.set_title(title)
    ax1.set_xlim(1.5,50)
    
    ax1.legend()

# %%
def NiPDF2(title=None):
    r1, g1, d1, c1 = np.loadtxt('./data/Ni.dat', skiprows=4).T

    fig, ax1 = plt.subplots(1, 1, figsize=[14,7])
    
#     ax1.plot([0.0],[0.0])
#     ax1.plot([0.0],[0.0])
#     ax1.plot(r1, d1-5)
    ax1.plot(r1, g1, lw=1, color='#D7CEC7')
    ax1.plot(r1, g1-1, lw=1, color='#565656')
    ax1.plot(r1, g1-2, lw=1, color='#76323F')
    ax1.plot(r1, g1-3, lw=1, color='#C09F80')
#     ax1.plot(r1, g1, lw=10, color='#18121E')
    #     ax1.plot(r1, c1, lw=2) 
   

    ax1.set_ylabel('$G(\AA^{-2})$' , fontsize=20)
    ax1.set_xlabel('$r(\AA)$' , fontsize=20)
    
    ax1.set_title(title)
    ax1.set_xlim(1.5,50)

# %%
sohamSeabornStyle()
NiPDF2('seaborn-custom')

# %%
def NiPDF3(title=None, w=2.0):
    r1, g1, d1, c1 = np.loadtxt('./data/Ni.dat', skiprows=4).T

    fig, ax1 = plt.subplots(1, 1, figsize=[14,7])
    
#     ax1.plot([0.0],[0.0])
#     ax1.plot([0.0],[0.0])
#     ax1.plot(r1, d1-5)

#     ax1.plot(r1, g1-1, lw=w, color='#1D2731')
#     ax1.plot(r1, g1-2, lw=w, color='#233237')

    ax1.plot(r1, g1-4, lw=w, color='#0B3C5D')
    ax1.plot(r1, g1-3, lw=w, color='#062F4F')
    ax1.plot(r1, g1-5, lw=w, color='#328CC1')
    
    ax1.plot(r1, g1-6, lw=w, color='#D9B310')
    
    
    ax1.plot(r1, g1-8, lw=w, color='#984B43')
    ax1.plot(r1, g1-7, lw=w, color='#B82601')
#     ax1.plot(r1, g1-9, lw=w, color='#3F3250')
    ax1.plot(r1, g1-10, lw=w, color='#57652A')
    
    ax1.plot(r1, g1-9, lw=w, color='#76323F')
    ax1.plot(r1, g1-11, lw=w, color='#626E60')
    
   
    ax1.plot(r1, g1-12, lw=w, color='#AB987A')
    ax1.plot(r1, g1-13, lw=w, color='#C09F80')
    ax1.plot(r1, g1-14, lw=w, color='#b0b0b0ff')
    
    
#     ax1.plot(r1, g1, lw=10, color='#18121E')
    #     ax1.plot(r1, c1, lw=2) 
   

    ax1.set_ylabel('$G(\AA^{-2})$' , fontsize=20)
    ax1.set_xlabel('$r(\AA)$' , fontsize=20)
    
    ax1.set_title(title)
    ax1.set_xlim(1.5,50)

# %%
# %matplotlib qt
sohamSeabornStyle()
NiPDF3('seaborn-soham')

# %%
anotherstyle()
NiPDF('billinge-style')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-2c8c027b3a63> in <module>()
# ----> 1 anotherstyle()
#       2 NiPDF('billinge-style')
#
# NameError: name 'anotherstyle' is not defined

# %%
dPath = './styles/'
style_files = os.listdir(dPath)
print style_files
print len(style_files)
# Out:
# ['seaborn-poster.mplstyle', 'billinge.mplstyle', 'seaborn-muted.mplstyle', 'seaborn-notebook.mplstyle', 'ggplot.mplstyle', 'seaborn-deep.mplstyle', 'seaborn-colorblind.mplstyle', 'seaborn-paper.mplstyle', 'bmh.mplstyle', 'seaborn-bright.mplstyle', 'seaborn-whitegrid.mplstyle', 'seaborn.mplstyle', 'grayscale.mplstyle', 'seaborn-dark.mplstyle', 'dark_background.mplstyle', 'seaborn-talk.mplstyle', 'classic.mplstyle', 'fivethirtyeight.mplstyle', 'seaborn-darkgrid.mplstyle', 'seaborn-ticks.mplstyle', 'seaborn-dark-palette.mplstyle', 'seaborn-white.mplstyle', 'seaborn-pastel.mplstyle']
# 23

# %%
for style in style_files:
    sns.reset_orig()
    plt.style.use(os.path.join(dPath, style))
    NiPDF1(style)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1ad28d716b78> in <module>()
#       2     sns.reset_orig()
#       3     plt.style.use(os.path.join(dPath, style))
# ----> 4     NiPDF1(style)
#
# NameError: name 'NiPDF1' is not defined

# %%
sns.set
